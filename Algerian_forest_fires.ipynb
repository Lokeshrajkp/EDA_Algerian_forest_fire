# %% [markdown]
# ## Algerian forest fire datset

# %% [markdown]
# ## Problem statement

# %% [markdown]
# ####  EDA on algerian forest fire dataset which contains two regions data(Bejara & Sidi Bel)to analyse the data attributes and its combination which caused fire in the history.Based on this preventive measures can be taken to avoid any such instances in the future.

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %%
#import os
#import urllib.request
#download_dir='./algerian_forest'
#download_url='https://github.com/Lokeshrajkp/Datasets/blob/main/Algerian_forest_fires_dataset_UPDATE.csv'
#os.makedirs(download_dir,exist_ok=True)
#filename=os.path.basename(download_url)
#file_path=os.path.join(download_dir,filename)
#urllib.request.urlretrieve(download_url,file_path)

# %%
df=pd.read_csv('C:\\Users\\LOKESHRAJ K P\\Downloads\\Algerian_forest_fires_dataset_UPDATE.csv',header=1)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.drop([122,123],inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.iloc[120:126]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 122  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 123  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 124  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
# 125  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2  5.6    1
#
#        Classes
# 120  not fire
# 121  not fire
# 122  not fire
# 123  not fire
# 124  not fire
# 125  not fire

# %%
df.iloc[122:124]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
# 123  02    06  2012          30  73  13     4  55.7  2.7  7.8  0.6  2.9  0.2
#
#        Classes
# 122  not fire
# 123  not fire

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 239  6.5       fire
# 240    0   not fire
# 241  0.2   not fire
# 242  0.7   not fire
# 243  0.5  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
# dtypes: object(14)
# memory usage: 26.8+ KB

# %% [markdown]
# ## Feature information
# ### All the attributes are in the object type
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
# Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
# FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely â€œFireâ€ and â€œnot Fireâ€

# %%
df.describe()
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   244   244   244         244  244  244   244   244  244  244  244  244
# unique   31     4     1          19   62   18    39   173  166  198  106  174
# top      01    07  2012          35   64   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
#
#         FWI Classes
# count   244       243
# unique  127         8
# top     0.4   fire
# freq     12       131

# %%
df.columns=df.columns.str.strip()

# %%
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI       Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
df.iloc[160:180]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC   DMC      DC   ISI   BUI  \
# 160  09    07  2012          36  43  15  1.9  82.3   9.4     9.9   3.2     9
# 161  10    07  2012          34  51  16  3.8  77.5     8     9.5     2   7.7
# 162  11    07  2012          34  56  15  2.9  74.8   7.1     9.5   1.6   6.8
# 163  12    07  2012          36  44  13    0  90.1  12.6    19.4   8.3  12.5
# 164  13    07  2012          39  45  13  0.6  85.2  11.3    10.4   4.2  10.9
# 165  14    07  2012          37  37  18  0.2  88.9  12.9  14.6 9  12.5  10.4
# 166  15    07  2012          34  45  17    0  90.5    18    24.1  10.9  17.7
# 167  16    07  2012          31  83  17    0  84.5  19.4    33.1   4.7  19.2
# 168  17    07  2012          32  81  17    0  84.6  21.1    42.3   4.7  20.9
# 169  18    07  2012          33  68  15    0  86.1  23.9    51.6   5.2  23.9
# 170  19    07  2012          34  58  16    0  88.1  27.8    61.1   7.3  27.7
# ...

# %%
df['DC']=df['DC'].replace('14.6 9','14.69')

# %%
df['FWI']=df['FWI'].str.replace('fire','0')

# %%
df['DC'].unique()
# Out:
# array(['7.6', '7.1', '6.9', '14.2', '22.2', '30.5', '38.3', '38.8',
#        '46.3', '54.3', '61.4', '17', '7.8', '7.4', '8', '16', '27.1',
#        '31.6', '39.5', '47.7', '55.8', '63.8', '71.8', '80.3', '88.5',
#        '84.4', '92.8', '8.6', '8.3', '9.2', '18.5', '27.9', '37', '40.4',
#        '49.8', '9.3', '18.7', '27.7', '37.2', '22.9', '25.5', '34.1',
#        '43.1', '52.8', '62.1', '71.5', '79.9', '71.3', '79.7', '88.7',
#        '98.6', '108.5', '117.8', '127', '136', '145.7', '10.2', '10',
#        '19.8', '29.7', '39.1', '48.6', '47', '57', '67', '77', '75.1',
#        '85.1', '94.7', '92.5', '90.4', '100.7', '110.9', '120.9', '130.6',
#        '141.1', '151.3', '161.5', '171.3', '181.3', '190.6', '200.2',
#        '210.4', '220.4', '180.4', '8.7', '7.5', '7', '15.7', '24', '32.2',
#        '30.1', '8.4', '8.9', '16.6', '7.3', '24.3', '33.1', '41.3',
#        '49.3', '57.9', '41.4', '30.4', '15.2', '7.7', '16.3', '24.9',
# ...

# %%
df['FWI'].unique()
# Out:
# array(['0.5', '0.4', '0.1', '0', '2.5', '7.2', '7.1', '0.3', '0.9', '5.6',
#        '7.1 ', '0.2', '1.4', '2.2', '2.3', '3.8', '7.5', '8.4', '10.6',
#        '15', '13.9', '3.9', '12.9', '1.7', '4.9', '6.8', '3.2', '8',
#        '0.6', '3.4', '0.8', '3.6', '6', '10.9', '4', '8.8', '2.8', '2.1',
#        '1.3', '7.3', '15.3', '11.3', '11.9', '10.7', '15.7', '6.1', '2.6',
#        '9.9', '11.6', '12.1', '4.2', '10.2', '6.3', '14.6', '16.1',
#        '17.2', '16.8', '18.4', '20.4', '22.3', '20.9', '20.3', '13.7',
#        '13.2', '19.9', '30.2', '5.9', '7.7', '9.7', '8.3', '0.7', '4.1',
#        '1', '3.1', '1.9', '10', '16.7', '1.2', '5.3', '6.7', '9.5', '12',
#        '6.4', '5.2', '3', '9.6', '4.7', '0   ', '14.1', '9.1', '13',
#        '17.3', '30', '25.4', '16.3', '9', '14.5', '13.5', '19.5', '12.6',
#        '12.7', '21.6', '18.8', '10.5', '5.5', '14.8', '24', '26.3',
#        '12.2', '18.1', '24.5', '26.9', '31.1', '30.3', '26.1', '16',
# ...

# %%
df.iloc[167,13]
# Out:
# 'fire   '

# %%
df=df.astype({'day':'int64','month':'int64','year':'int64','Temperature':'int64','RH':'int64','Ws':'int64','Rain':'float64','FFMC':'float64','DMC':'float64','DC':'float64','ISI':'float64','BUI':'float64','FWI':'float64'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 26.8+ KB

# %%
# There are two regions Bejaia & Sidi-Bel Abbes Region
# Bejaia-0  & Sidi-Bel Abbes-1(Identification by numerical value)
df['Region']=[0 if i<=121 else 1 for i in df.index]

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
# The changed feature dataypes as below for better understanding
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.7+ KB

# %%
# Checking null value in the datset
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# Region         0
# dtype: int64

# %%
feature_with_na=[feature for feature in df.columns if df[feature].isnull().sum()>=1]

# %%
feature_with_na
# Out:
# ['Classes']

# %% [markdown]
# ### Target feature 'Classes' has null value & we need to handle it

# %%
df[df['Classes'].isna()] #or df[df.isna().any(axis=1)]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC     DC   ISI  \
# 165   14      7  2012           37  37  18   0.2  88.9  12.9  14.69  12.5
#
#       BUI  FWI Classes  Region
# 165  10.4  0.0     NaN       1

# %%
#df['Classes'].fillna((df[df['Region']==1]['Classes'].mode()).astype(object),inplace=True)

# %%
df[df['Region']==1]['Classes'].mode()
# Out:
# 0    fire
# Name: Classes, dtype: object

# %%
df['Classes'].fillna('fire',inplace=True)

# %%
df[df['Classes'].isna()]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature, RH, Ws, Rain, FFMC, DMC, DC, ISI, BUI, FWI, Classes, Region]
# Index: []

# %%
df.iloc[165]
# Out:
# day               14
# month              7
# year            2012
# Temperature       37
# RH                37
# Ws                18
# Rain             0.2
# FFMC            88.9
# DMC             12.9
# DC             14.69
# ISI             12.5
# BUI             10.4
# FWI              0.0
# Classes         fire
# Region             1
# Name: 165, dtype: object

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# ...

# %%
# Numerical features
num_features=[feature for feature in df.columns if df[feature].dtype!='O']

# %%
num_features
# Out:
# ['day',
#  'month',
#  'year',
#  'Temperature',
#  'RH',
#  'Ws',
#  'Rain',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'BUI',
#  'FWI',
#  'Region']

# %%
len(num_features)
# Out:
# 14

# %%
# Catrgorical features
cat_features=[feature for feature in df.columns if df[feature].dtype=='O']

# %%
cat_features
# Out:
# ['Classes']

# %%
print('We have {} numerical features : {}'.format(len(num_features), num_features))
print('\nWe have {} categorical features : {}'.format(len(cat_features), cat_features))
# Out:
# We have 14 numerical features : ['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Region']
#
# We have 1 categorical features : ['Classes']

# %%
for col in cat_features:
    print(df[col].value_counts())
# Out:
# fire             131
# not fire         101
# fire               5
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
df['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'not fire     ', 'not fire    '], dtype=object)

# %%
for feature in ['Classes']:
    df[feature]=df[feature].str.strip()  # or df[feature].str.replace(' ','')

# %%
df['Classes'].unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %% [markdown]
# ## Univariate analysis

# %% [markdown]
# ### Numerical features

# %%
# Graphical representation of numerical features
plt.figure(figsize=(25,25))
plt.suptitle('Univariate analysis of numerical features',fontsize=30,fontweight='bold',alpha=0.6,y=1)
for i in range(0,len(num_features)):
    plt.subplot(5,3,i+1)
    plt.subplots_adjust(left=0.5,bottom=0.5,right=1,top=2,wspace=1,hspace=1)
    plt.rcParams['font.size'] = '25'
    sns.kdeplot(df[num_features[i]],shade=True,color='dodgerblue')
    plt.tight_layout(h_pad=2,w_pad=2)

# %% [markdown]
# ### Observations
# 1. Features RH,WS,FFMC are left skewed(Non normal distribution need to convert to normal distribution)
# 2. Feature Rain,DMC,DC,ISI,BUI,FWI are right skewed(Non normal distribution need to convert to normal distribution)

# %%
# Discrete feature
Discrete_features=[feature for feature in num_features if len(df[feature].unique())<10]

# %%
Discrete_features
# Out:
# ['month', 'year', 'Region']

# %%
print('\nWe have {} Discrete features : {}'.format(len(Discrete_features), Discrete_features))
# Out:
# We have 3 Discrete features : ['month', 'year', 'Region']

# %%
# Continous feature
continous_features=[feature for feature in num_features if feature not in Discrete_features]

# %%
continous_features
# Out:
# ['day',
#  'Temperature',
#  'RH',
#  'Ws',
#  'Rain',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'BUI',
#  'FWI']

# %%
print('\nWe have {} continous features : {}'.format(len(continous_features),continous_features))
# Out:
# We have 11 continous features : ['day', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']

# %%
plt.figure(figsize=(25,25))
for i in range(0,len(continous_features)):
    plt.subplot(5,3,i+1)
    plt.subplots_adjust(left=0.5,bottom=0.5,right=1,top=2,wspace=1,hspace=1)
    plt.rcParams['font.size'] = '25'
    sns.histplot(df[continous_features[i]],color='g',kde=True)
    plt.tight_layout(h_pad=2,w_pad=2)

# %% [markdown]
# #### Tempertaure in different days

# %%
sns.lineplot(x='day',y='Temperature',data=df,color='magenta')
# Out:
# <AxesSubplot:xlabel='day', ylabel='Temperature'>

# %% [markdown]
# #### Tempertaure in different month

# %%
sns.jointplot(data=df,x='month',y='Temperature',color='cyan')

# %% [markdown]
# #### Day vs Temperature

# %%
plt.style.use('default')
sns.barplot(x='day',y='Temperature',data=df)
plt.title('Day vs Temperature',fontsize=10)
plt.xlabel('day')
plt.ylabel('Temperature')
plt.show()

# %%
df.Temperature.max()
# Out:
# 42

# %%
df.Temperature.min()
# Out:
# 22

# %% [markdown]
# #### Highest rainfall

# %%
highest_rain=df.sort_values(by='Rain',ascending=False)[['Rain','day','month']].head(1)

# %%
highest_rain
# Out:
#     Rain  day  month
# 91  16.8   31      8

# %% [markdown]
# #### lowest rainfall

# %%
lowest_rain=df.sort_values(by='Rain',ascending=True)[['Rain','day','month']].head(1)

# %%
lowest_rain
# Out:
#    Rain  day  month
# 0   0.0    1      6

# %% [markdown]
# ### Observation
# * Highest rain in 31/08/2012 with 16.8mm
# * Lowest rain in 1/6/2012 with 0mm.means no rain

# %% [markdown]
# ### Outliers identification

# %%
plt.figure(figsize=(25,25))
for i in range(0,len(continous_features[1:])):
    plt.subplot(5,3,i+1)
    plt.subplots_adjust(left=0.5,bottom=0.5,right=1,top=2,wspace=1,hspace=1)
    plt.rcParams['font.size'] = '25'
    sns.boxplot(df[continous_features[1:][i]],color='g')
    plt.tight_layout(h_pad=2,w_pad=2)

# %% [markdown]
# ### Observations
# * Temperature & RH features has no significant outliers
# * WS feature has outlier on lower & upper side
# * FFMC feature has outlier on lower side only
# * Rain,DMC,DC,ISI,BUI,FWI are having outlier on the upper side

# %% [markdown]
# ## Multivariate analysis

# %%
df[num_features].corr()
# Out:
#                       day         month  year  Temperature        RH  \
# day          1.000000e+00  2.232788e-17   NaN     0.095772 -0.074209
# month        2.232788e-17  1.000000e+00   NaN    -0.059017 -0.037884
# year                  NaN           NaN   NaN          NaN       NaN
# Temperature  9.577222e-02 -5.901677e-02   NaN     1.000000 -0.654443
# RH          -7.420934e-02 -3.788419e-02   NaN    -0.654443  1.000000
# Ws           4.700086e-02 -4.144673e-02   NaN    -0.278132  0.236084
# Rain        -1.122654e-01  3.532207e-02   NaN    -0.326786  0.222968
# FFMC         2.240321e-01  1.557668e-02   NaN     0.677491 -0.645658
# DMC          4.915710e-01  6.817778e-02   NaN     0.483105 -0.405133
# DC           5.279300e-01  1.276691e-01   NaN     0.370511 -0.220344
# ISI          1.777266e-01  6.168011e-02   NaN     0.607551 -0.690637
# BUI          5.172292e-01  8.582162e-02   NaN     0.455504 -0.348587
# FWI          3.508824e-01  8.420132e-02   NaN     0.558393 -0.569997
# ...

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df[num_features].corr(),cmap='viridis',annot=True, annot_kws={'size':10},linewidth=5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Observation
# * day is having positive correlation with DMC,DC,ISI,BUI & PWI
# * Temperature is positively correlated with FFMC,DMC,ISI,BUI,FWI.Particularly high with FFMC
# * Tempearture is having negative correlation with RH,WS & Rain(It's usual that when rain is low temperature will be high)
# * FFMC,DMC,DC,BUI,FMI are more positively correlated with each other.
#  * BUI & DMC are 98% correlated and one feature can be neglected in the feature selection.
#  * BUI & DC are also 94% correlated.
#  * RH is almost negatively or less positively correlated with other features.
#     If we find the relation between RH & target feature then we can set threshold RH value above/below which fire occurs
#     normally.Then we can control RH to prevent fires.

# %%
sns.pairplot(df[num_features])

# %% [markdown]
# ## Categorical feature

# %%
plt.rcParams['font.size'] = '10'
sns.countplot(df['Classes'],data=df)
# Out:
# <AxesSubplot:xlabel='Classes', ylabel='count'>

# %%
df['Classes'].value_counts()
# Out:
# fire        138
# not fire    106
# Name: Classes, dtype: int64

# %% [markdown]
# ### Observations
# * There are 138 fire incidents occured which are more when compared to non fire incidents(106)

# %% [markdown]
# #### Fire incidents based on regions

# %%
plt.rcParams['font.size'] = '10'
sns.countplot(data=df,x='Region',hue='Classes')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# ### Observations
# * In Sidi bel-abbes region fire is occuring more compared to Bejaia region.
# * Bejara
#   * Fire-->59
#   * Non fire--> 63
# * Sidi bel
#    * Fire--> 79
#    * Non fire--> 43

# %%
df[df['Region']==1]['Classes'].value_counts()
# Out:
# fire        79
# not fire    43
# Name: Classes, dtype: int64

# %%
df[df['Region']==0]['Classes'].value_counts()
# Out:
# not fire    63
# fire        59
# Name: Classes, dtype: int64

# %% [markdown]
# ### Monthly statistics

# %%
sns.countplot(data=df,x='month',hue='Classes')
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %% [markdown]
# #### More no of fire incidents happed in the september month
# * Need to analyse the attibutes of this month to take countemeasures

# %%
df[df['month']==8]['Classes'].value_counts()
# Out:
# fire        51
# not fire    11
# Name: Classes, dtype: int64

# %% [markdown]
# ### Relation between Temperature and Target feature

# %%
sns.countplot(data=df,x='Temperature',hue='Classes')
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='count'>

# %% [markdown]
# ### Observation
# * When tempearure crosses 31 degree celcius chances of fire is high and above 40 degree celcius only fire occcured.

# %% [markdown]
# ### Daywise fire or No fire data

# %%
sns.countplot(data=df,x='day',hue='Classes')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %% [markdown]
# # Report

# %% [markdown]
# * Highest rain in 31/08/2012 with 16.8mm
# * Lowest rain in 1/6/2012 with 0mm.means no rain
# * Temperature & RH features has no significant outliers
# * WS feature has outlier on lower & upper side
# * FFMC feature has outlier on lower side only
# * Rain,DMC,DC,ISI,BUI,FWI are having outlier on the upper side
# * day is having positive correlation with DMC,DC,ISI,BUI & PWI
# * Temperature is positively correlated with FFMC,DMC,ISI,BUI,FWI.Particularly high with FFMC
# * Tempearture is having negative correlation with RH,WS & Rain(It's usual that when rain is low temperature will be high)
# * FFMC,DMC,DC,BUI,FMI are more positively correlated with each other.
# * BUI & DMC are 98% correlated and one feature can be neglected in the feature selection.
# * BUI & DC are also 94% correlated.
# * RH is almost negatively or less positively correlated with other features.
#   If we find the relation between RH & target feature then we can set threshold RH value above/below which fire
#   occurs normally.Then we can control RH to prevent fires.
#
#
# * There are 138 fire incidents occured which are more when compared to non fire incidents(106)
# * When tempearure crosses 31 degree celcius chances of fire is high and above 40 degree celcius only fire occcured.
# * More no of fire incidents happed in the september month,Need to analyse the attibutes of this month to take countemeasures
# * In Sidi bel-abbes region fire is occuring more compared to Bejaia region.
# * Bejara
#   * Fire-->59
#   * Non fire--> 63
# * Sidi bel
#    * Fire--> 79
#    * Non fire--> 43
